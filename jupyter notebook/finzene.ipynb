# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:\STIGE INTERNSHIP/finzene.csv')
df.head(5)
# Out:
#                     Name (Original Name)                 User Email  \
# 0                            Bhanu Priya     bhanu.p47961@gmail.com
# 1  Abhinav (Abhinav# Volunteer# C HELIX)  abhinavgarg8864@gmail.com
# 2                                Bhav na      bhavna62678@gmail.com
# 3          Gayatri ciel (CIEL Trainings)    sonal.sharma@ciel.co.in
# 4                           Anjali Manda     anjali_manda@yahoo.com
#
#    Total Duration (Minutes) Guest
# 0                        60   Yes
# 1                        96   Yes
# 2                       104   Yes
# 3                       111    No
# 4                       114   Yes

# %%
df.tail(5)
# Out:
#     Name (Original Name)                 User Email  Total Duration (Minutes)  \
# 127   Prateek Srivastava  sri.prateek1001@gmail.com                         7
# 128        Nikhil Shukla        20bce049@nith.ac.in                         3
# 129             Pm Singh        21bme099@nith.ac.in                         2
# 130        sachin sharma        21bce007@nith.ac.in                         2
# 131      Kinshuk Sharely        20dcs024@nith.ac.in                         1
#
#     Guest
# 127   Yes
# 128   Yes
# 129   Yes
# 130   Yes
# 131   Yes

# %%
print(df.columns)
# Out:
# Index(['Name (Original Name)', 'User Email', 'Total Duration (Minutes)',
#        'Guest'],
#       dtype='object')

# %%
print(df)
# Out:
#                       Name (Original Name)                 User Email  \
# 0                              Bhanu Priya     bhanu.p47961@gmail.com
# 1    Abhinav (Abhinav# Volunteer# C HELIX)  abhinavgarg8864@gmail.com
# 2                                  Bhav na      bhavna62678@gmail.com
# 3            Gayatri ciel (CIEL Trainings)    sonal.sharma@ciel.co.in
# 4                             Anjali Manda     anjali_manda@yahoo.com
# ..                                     ...                        ...
# 127                     Prateek Srivastava  sri.prateek1001@gmail.com
# 128                          Nikhil Shukla        20bce049@nith.ac.in
# 129                               Pm Singh        21bme099@nith.ac.in
# 130                          sachin sharma        21bce007@nith.ac.in
# 131                        Kinshuk Sharely        20dcs024@nith.ac.in
#
#      Total Duration (Minutes) Guest
# 0                          60   Yes
# 1                          96   Yes
# ...

# %% [markdown]
# # Print Data via Excel File

# %%
#df_xlsx= pd.read_excel('finzene_csv.xlsx')
#print(df_xlsx)

# %% [markdown]
# # Reading Data in Pandas

# %%
#Read each headers
print(df.columns)

# Read each columns
print(df[['User Email']])
#Read each row
print(df[1:10])
print(df.iloc[:10,1:3])
#Read a specific value
print(df.iloc[1,1])
# Out:
# Index(['Name (Original Name)', 'User Email', 'Total Duration (Minutes)',
#        'Guest'],
#       dtype='object')
#                     User Email
# 0       bhanu.p47961@gmail.com
# 1    abhinavgarg8864@gmail.com
# 2        bhavna62678@gmail.com
# 3      sonal.sharma@ciel.co.in
# 4       anjali_manda@yahoo.com
# ..                         ...
# 127  sri.prateek1001@gmail.com
# 128        20bce049@nith.ac.in
# 129        21bme099@nith.ac.in
# 130        21bce007@nith.ac.in
# 131        20dcs024@nith.ac.in
#
# [132 rows x 1 columns]
#                          Name (Original Name)                 User Email  \
# 1       Abhinav (Abhinav# Volunteer# C HELIX)  abhinavgarg8864@gmail.com
# 2                                     Bhav na      bhavna62678@gmail.com
# 3               Gayatri ciel (CIEL Trainings)    sonal.sharma@ciel.co.in
# 4                                Anjali Manda     anjali_manda@yahoo.com
# 5                          Finzene (Sonali B)      sonalisimsr@gmail.com
# ...

# %%
df.loc[df['User Email']== "shubhamagarwal7219@gmail.com"]
# Out:
#          Name (Original Name)                    User Email  \
# 12  Shubham (Shubham Agarwal)  shubhamagarwal7219@gmail.com
#
#     Total Duration (Minutes) Guest
# 12                       101   Yes

# %%
df.describe()
# Out:
#        Total Duration (Minutes)
# count                132.000000
# mean                  45.765152
# std                   37.777545
# min                    1.000000
# 25%                    5.000000
# 50%                   41.000000
# 75%                   83.000000
# max                  121.000000

# %%
df.sort_values(['Name (Original Name)','User Email'],ascending =True)
# Out:
#                       Name (Original Name)                       User Email  \
# 65                                     A B          tonyiron12345@gmail.com
# 126                                    A R                     ar@gmail.com
# 122                           AKSHAY SINGH       akshaysinghabhi6@gmail.com
# 33               Aanchal (Aanchal Chauhan)              21bce035@nith.ac.in
# 1    Abhinav (Abhinav# Volunteer# C HELIX)        abhinavgarg8864@gmail.com
# ..                                     ...                              ...
# 130                          sachin sharma              21bce007@nith.ac.in
# 37                              sahil khan            ksahil86049@gmail.com
# 21                           shubham goyal        shubham327goyal@gmail.com
# 102                       shubham nautiyal  shubham.nautiyal20602@gmail.com
# 125                        vishal bhardwaj              20bce111@nith.ac.in
#
#      Total Duration (Minutes) Guest
# ...
